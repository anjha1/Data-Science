# %% [markdown]
# [Download csv file](https://drive.google.com/file/d/10rhOZhjVWToi8KnnvLYTb9r0RlHt7Fhe/view?usp=sharing)

# %% [markdown]
# [link 10_Pivot Tables_CW ](https://docs.google.com/spreadsheets/d/1uBYaoRpOwLzIhP9yDOmjm7RGICPO5paC/edit?usp=sharing&ouid=106333942476934557329&rtpof=true&sd=true)

# %% [markdown]
# [link github titanic.csv](https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv)

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
df=pd.read_csv("/content/Employee_Performance.csv")

# %%
df.head()
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001007   40    Male       Life Sciences       Married         Sales
# 1  E1001025   30    Male           Marketing      Divorced         Sales
# 2  E1001054   52    Male           Marketing       Married         Sales
# 3  E1001059   25  Female             Medical        Single         Sales
# 4  E1001064   34    Male               Other        Single         Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive       Travel_Frequently                 5
# 1  Sales Executive           Travel_Rarely                27
# 2          Manager           Travel_Rarely                 3
# 3  Sales Executive           Travel_Rarely                26
# 4  Sales Executive           Travel_Rarely                 2
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  4  ...                            3
# ...

# %%
df.tail()
# Out:
#    EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 81   E100724   33    Male           Marketing        Single         Sales
# 82   E100891   31    Male       Life Sciences      Divorced         Sales
# 83   E100985   25    Male       Life Sciences       Married         Sales
# 84   E100987   38  Female           Marketing        Single         Sales
# 85   E100992   27  Female             Medical      Divorced         Sales
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 81  Sales Executive       Travel_Frequently                10
# 82          Manager           Travel_Rarely                 7
# 83  Sales Executive           Travel_Rarely                 8
# 84  Sales Executive           Travel_Rarely                 7
# 85  Sales Executive       Travel_Frequently                 3
#
#     EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 81                  3  ...                            3
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['EmpNumber',
#  'Age',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'DistanceFromHome',
#  'EmpEducationLevel',
#  'EmpEnvironmentSatisfaction',
#  'EmpHourlyRate',
#  'EmpJobInvolvement',
#  'EmpJobLevel',
#  'EmpJobSatisfaction',
#  'NumCompaniesWorked',
#  'OverTime',
#  'EmpLastSalaryHikePercent',
#  'EmpRelationshipSatisfaction',
#  'TotalWorkExperienceInYears',
#  'TrainingTimesLastYear',
#  'EmpWorkLifeBalance',
#  'ExperienceYearsAtThisCompany',
#  'ExperienceYearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'Attrition',
#  'PerformanceRating']

# %%
df.Age
# Out:
# 0     40
# 1     30
# 2     52
# 3     25
# 4     34
#       ..
# 81    33
# 82    31
# 83    25
# 84    38
# 85    27
# Name: Age, Length: 86, dtype: int64

# %%
df['Age']
# Out:
# 0     40
# 1     30
# 2     52
# 3     25
# 4     34
#       ..
# 81    33
# 82    31
# 83    25
# 84    38
# 85    27
# Name: Age, Length: 86, dtype: int64

# %%
df[['EmpNumber']]
# Out:
#    EmpNumber
# 0   E1001007
# 1   E1001025
# 2   E1001054
# 3   E1001059
# 4   E1001064
# ..       ...
# 81   E100724
# 82   E100891
# 83   E100985
# 84   E100987
# 85   E100992
#
# [86 rows x 1 columns]

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['EmpNumber']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['EmpNumber', 'Age', 'Gender']]
# Out:
#    EmpNumber  Age  Gender
# 0   E1001007   40    Male
# 1   E1001025   30    Male
# 2   E1001054   52    Male
# 3   E1001059   25  Female
# 4   E1001064   34    Male
# ..       ...  ...     ...
# 81   E100724   33    Male
# 82   E100891   31    Male
# 83   E100985   25    Male
# 84   E100987   38  Female
# 85   E100992   27  Female
#
# [86 rows x 3 columns]

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# EmpNumber                       object
# Age                              int64
# Gender                          object
# EducationBackground             object
# MaritalStatus                   object
# EmpDepartment                   object
# EmpJobRole                      object
# BusinessTravelFrequency         object
# DistanceFromHome                 int64
# EmpEducationLevel                int64
# EmpEnvironmentSatisfaction       int64
# EmpHourlyRate                    int64
# EmpJobInvolvement                int64
# EmpJobLevel                      int64
# EmpJobSatisfaction               int64
# NumCompaniesWorked               int64
# OverTime                        object
# EmpLastSalaryHikePercent         int64
# EmpRelationshipSatisfaction      int64
# TotalWorkExperienceInYears       int64
# TrainingTimesLastYear            int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# ...

# %%
df1=pd.read_excel("/content/10_Pivot Tables_CW.xlsx", sheet_name="Proper Data Set")

# %%
df1
# Out:
#          Date     Region SalesRep  Sales  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  2017-10-20       West     Gigi    620         NaN         NaN         NaN
# 1  2017-10-20  Northwest     Gigi    484         NaN         NaN         NaN
# 2  2017-10-20       West   Freddy    376         NaN         NaN         NaN
# 3  2017-10-20  Northwest   Freddy   1141         NaN         NaN         NaN
# 4  2017-10-20  Northwest     Chin    725         NaN         NaN         NaN
# 5  2017-10-20       West     Chin    222         NaN         NaN         NaN
# 6  2017-10-20       West     June   1038         NaN         NaN         NaN
# 7  2017-10-21  Northwest     Chin    154         NaN         NaN         NaN
# 8  2017-10-21  Northwest     Gigi    205         NaN         NaN         NaN
# 9  2017-10-21  Southwest     Gigi    895         NaN         NaN         NaN
# 10 2017-10-21       West     Chin   1254         NaN         NaN         NaN
# ...

# %%
df1.dtypes
# Out:
# Date          datetime64[ns]
# Region                object
# SalesRep              object
# Sales                  int64
# Unnamed: 4           float64
# Unnamed: 5           float64
# Unnamed: 6           float64
# Unnamed: 7            object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Date', 'Region', 'SalesRep', 'Sales', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
df1[['Date', 'Region', 'SalesRep', 'Sales']]
# Out:
#          Date     Region SalesRep  Sales
# 0  2017-10-20       West     Gigi    620
# 1  2017-10-20  Northwest     Gigi    484
# 2  2017-10-20       West   Freddy    376
# 3  2017-10-20  Northwest   Freddy   1141
# 4  2017-10-20  Northwest     Chin    725
# 5  2017-10-20       West     Chin    222
# 6  2017-10-20       West     June   1038
# 7  2017-10-21  Northwest     Chin    154
# 8  2017-10-21  Northwest     Gigi    205
# 9  2017-10-21  Southwest     Gigi    895
# 10 2017-10-21       West     Chin   1254
# 11 2017-10-22  Northwest     June    596
# 12 2017-10-24  Southwest     Gigi    799
# 13 2017-10-24  Northwest     Gigi    651
# 14 2017-10-24       West     June   1235
# 15 2017-10-24  Southwest     Chin    684
# 16 2017-10-24  Northwest     June    127
# 17 2017-10-24       West     June    269
# 18 2017-10-25  Southwest     Chin    739
# 19 2017-10-25       West     Gigi   1201
# 20 2017-10-25  Northwest     June    546
# 21 2017-10-25  Northwest     Chin    162

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=['PassengerId', 'Survived', 'Pclass'])
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3=url_data[0]
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.to_csv("players_data.csv",index=False)
