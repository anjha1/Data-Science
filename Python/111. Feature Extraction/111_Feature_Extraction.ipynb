# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/111.%20Feature%20Extraction/111_Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Feature Extraction**
#
# Feature Extraction is the process of selecting and extracting the most important features from raw data.
#
# **ML Application**
# → 1000 features
# ↓
# Most Important features
# ↓
# Machine Learning Algo.

# %% [markdown]
# **Normalization (Min-Max Scaling):**
# Scales all features to fit within a specific range, usually [0, 1].

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Standardization (Z-score Normalization):**
# Scales features to have a mean of 0 and a standard deviation of 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Principal component analysis (PCA) :**- reduces the number of dimensions in large datasets to principal components that retain most of the original information.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [For more, you can visit my site at......](https://sites.google.com/view/achhuta-nand-jha/specialization/data-science)
