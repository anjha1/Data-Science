# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/113.%20Normalization%20Min%20Max%20Scaling/113_Normalization_Min_Max_Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Normalization Min Max Scaller**

# %%
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
k=min_max.fit_transform(df[['distance', 'fare', 'tip']])

# %%
import pandas as pd
df1=pd.DataFrame(k,columns=['distance', 'fare', 'tip'])
df1
# Out:
#       distance      fare       tip
# 0     0.043597  0.040268  0.064759
# 1     0.021526  0.026846  0.000000
# 2     0.037330  0.043624  0.071084
# 3     0.209809  0.174497  0.185241
# 4     0.058856  0.053691  0.033133
# ...        ...       ...       ...
# 6428  0.020436  0.023490  0.031928
# 6429  0.510627  0.382550  0.000000
# 6430  0.112807  0.100671  0.000000
# 6431  0.030518  0.033557  0.000000
# 6432  0.104905  0.093960  0.101205
#
# [6433 rows x 3 columns]

# %%
sns.histplot(df['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
sns.histplot(df1['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>
