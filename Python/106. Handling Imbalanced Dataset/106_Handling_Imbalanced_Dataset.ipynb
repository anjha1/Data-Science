# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/106.%20Handling%20Imbalanced%20Dataset/106_Handling_Imbalanced_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imbalanced Dataset Handling**
#
#
#
# 1.   Upsampling
# 2.   Down Sampling

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(123)   # the same sequence of random numbers is generated every time you run this code.
n_samples = 1000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

# %%
n_class_0,n_class_1
# Out:
# (900, 100)

# %%
class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

# %%
class_0
# Out:
#      feature_1  feature_2  target
# 0    -1.085631   0.551302       0
# 1     0.997345   0.419589       0
# 2     0.282978   1.815652       0
# 3    -1.506295  -0.252750       0
# 4    -0.578600  -0.292004       0
# ..         ...        ...     ...
# 895   0.238761  -0.003155       0
# 896  -1.106386  -0.430660       0
# 897   0.366732  -0.146416       0
# 898   1.023906   1.160176       0
# 899  -0.210056  -0.641512       0
#
# [900 rows x 3 columns]

# %%
class_1
# Out:
#     feature_1  feature_2  target
# 0    1.699768   2.139033       1
# 1    1.367739   2.025577       1
# 2    1.795683   1.803557       1
# 3    2.213696   3.312255       1
# 4    3.033878   3.187417       1
# ..        ...        ...     ...
# 95   1.376371   2.845701       1
# 96   2.239810   0.880077       1
# 97   1.131760   1.640703       1
# 98   2.902006   0.390305       1
# 99   2.697490   2.013570       1
#
# [100 rows x 3 columns]

# %%
df = pd.concat([class_0, class_1]).reset_index(drop=True)
df.head()
# Out:
#    feature_1  feature_2  target
# 0  -1.085631   0.551302       0
# 1   0.997345   0.419589       0
# 2   0.282978   1.815652       0
# 3  -1.506295  -0.252750       0
# 4  -0.578600  -0.292004       0

# %%
df.tail()
# Out:
#      feature_1  feature_2  target
# 995   1.376371   2.845701       1
# 996   2.239810   0.880077       1
# 997   1.131760   1.640703       1
# 998   2.902006   0.390305       1
# 999   2.697490   2.013570       1

# %%
df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %% [markdown]
# **Upsampling**

# %%
df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

# %%
df_minority.head()
# Out:
#      feature_1  feature_2  target
# 900   1.699768   2.139033       1
# 901   1.367739   2.025577       1
# 902   1.795683   1.803557       1
# 903   2.213696   3.312255       1
# 904   3.033878   3.187417       1

# %%
df_majority.head()
# Out:
#    feature_1  feature_2  target
# 0  -1.085631   0.551302       0
# 1   0.997345   0.419589       0
# 2   0.282978   1.815652       0
# 3  -1.506295  -0.252750       0
# 4  -0.578600  -0.292004       0

# %% [markdown]
# **Upsampling Perform**

# %%
from sklearn.utils import resample
df_minority_upsampled = resample(df_minority,
                                  replace=True, # sample with replacement
                                  n_samples=len(df_majority), # match number in majority class
                                  random_state=42
                                  )

# %%
df_minority_upsampled.shape
# Out:
# (900, 3)

# %%
df_minority_upsampled.head()
# Out:
#      feature_1  feature_2  target
# 951   1.125854   1.843917       1
# 992   2.196570   1.397425       1
# 914   1.932170   2.998053       1
# 971   2.272825   3.034197       1
# 960   2.870056   1.550485       1

# %%
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
df_upsampled['target'].value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
df_upsampled.shape
# Out:
# (1800, 3)

# %% [markdown]
# **Down Sampling**

# %%
np.random.seed(123)   # the same sequence of random numbers is generated every time you run this code.
n_samples = 1000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

# %%
class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

# %%
df1 = pd.concat([class_0, class_1]).reset_index(drop=True)
df1.head()
# Out:
#    feature_1  feature_2  target
# 0  -1.085631   0.551302       0
# 1   0.997345   0.419589       0
# 2   0.282978   1.815652       0
# 3  -1.506295  -0.252750       0
# 4  -0.578600  -0.292004       0

# %%
df1['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
df1_minority=df1[df1['target']==1]
df1_majority=df1[df1['target']==0]

# %%
from sklearn.utils import resample
df1_majority_upsampled = resample(df1_majority,
                                  replace=False, # sample without replacement
                                  n_samples=len(df1_minority), # match number in minority class
                                  random_state=42
                                  )

# %%
df1_minority.shape
# Out:
# (100, 3)

# %%
df1_majority.shape
# Out:
# (900, 3)

# %%
df1_majority_upsampled.shape
# Out:
# (100, 3)

# %%
df1_downsampled = pd.concat([df1_minority, df1_majority_upsampled])

# %%
df1_downsampled.shape
# Out:
# (200, 3)
