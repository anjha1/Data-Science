# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/121.%20Covariance%20And%20Correlation%20with%20Python/121_Covariance_And_Correlation_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Covariance And Correlation**

# %%
import seaborn as sns

# %%
df=sns.load_dataset('healthexp')
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
# Select only numeric columns before calculating covariance
numerical_df = df.select_dtypes(include=['number'])

# Calculate covariance for the numeric columns only
covariance_matrix = numerical_df.cov()

covariance_matrix
# Out:
#                          Year  Spending_USD  Life_Expectancy
# Year               201.098848  2.571883e+04        41.915454
# Spending_USD     25718.827373  4.817761e+06      4166.800912
# Life_Expectancy     41.915454  4.166801e+03        10.733902

# %% [markdown]
# # **Pearson correlation coefficient**

# %%
numerical_df.corr(method='pearson')
# Out:
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.826273         0.902175
# Spending_USD     0.826273      1.000000         0.579430
# Life_Expectancy  0.902175      0.579430         1.000000

# %% [markdown]
# # **Spearman's rank correlation coefficient**

# %%
numerical_df.corr(method='spearman')
# Out:
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.931598         0.896117
# Spending_USD     0.931598      1.000000         0.747407
# Life_Expectancy  0.896117      0.747407         1.000000

# %%
numerical_df.var()
# Out:
# Year               2.010988e+02
# Spending_USD       4.817761e+06
# Life_Expectancy    1.073390e+01
# dtype: float64
