# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/203.%20Local%20Outlier%20Factor%20Anamoly%20Detection/Local_Outlier_Factor_Anamoly_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_circles

# %%
X,y=make_circles(n_samples=750,factor=0.3,noise=0.1)

# %%
plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# [link LocalOutlierFactor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
from sklearn.neighbors import LocalOutlierFactor
localout=LocalOutlierFactor(n_neighbors=20,contamination='auto')
localout.fit(X)
# Out:
# LocalOutlierFactor()

# %%
plt.scatter(X[:,0],X[:,1],c=localout.fit_predict(X))

# %%
import pandas as pd
import gdown

# Google Drive file ID
file_id = "1Ea8fFV2Ldg6a1mrTTuVhViSTWa1DqdUY"
url = f"https://drive.google.com/uc?id={file_id}"

# Download the file
output = "anjha_file.csv"
gdown.download(url, output, quiet=False)

# Read the CSV file
df = pd.read_csv(output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ea8fFV2Ldg6a1mrTTuVhViSTWa1DqdUY
# To: /content/anjha_file.csv
# 100%|██████████| 5.24k/5.24k [00:00<00:00, 4.07MB/s]

# %%
import matplotlib.pyplot as plt
plt.scatter(df.iloc[:,0],df.iloc[:,1])
plt.show()

# %%
from sklearn.neighbors import LocalOutlierFactor
localout=LocalOutlierFactor(n_neighbors=20,contamination='auto')
localout.fit(df)
# Out:
# LocalOutlierFactor()

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1],c=localout.fit_predict(df))
plt.show()
