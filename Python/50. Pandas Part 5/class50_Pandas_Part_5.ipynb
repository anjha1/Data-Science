# %% [markdown]
# <a href="https://colab.research.google.com/github/anjha1/Data-Science/blob/main/Python/50.%20Pandas%20Part%205/class50_Pandas_Part_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={"a":[1,2,3,4],"b":[5,6,7,8],"c":["sudh","krish","hitesh","navin"]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    a  b       c
# 0  1  5    sudh
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  5    sudh
# 2  6   krish
# 3  7  hitesh
# 4  8   navin

# %%
df=df.reset_index()
df
# Out:
#    a  b       c
# 0  1  5    sudh
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
data
# Out:
# {'a': [1, 2, 3, 4],
#  'b': [5, 6, 7, 8],
#  'c': ['sudh', 'krish', 'hitesh', 'navin']}

# %%
df1=pd.DataFrame(data,index=['a','b','c','d'])
df1
# Out:
#    a  b       c
# a  1  5    sudh
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin

# %%
df1.reindex(['b','a','d','c'])
# Out:
#    a  b       c
# b  2  6   krish
# a  1  5    sudh
# d  4  8   navin
# c  3  7  hitesh

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('a', a       1
# b       5
# c    sudh
# Name: a, dtype: object)
# ('b', a        2
# b        6
# c    krish
# Name: b, dtype: object)
# ('c', a         3
# b         7
# c    hitesh
# Name: c, dtype: object)
# ('d', a        4
# b        8
# c    navin
# Name: d, dtype: object)

# %%
for i,j in df1.iterrows():
    print(i,j)
# Out:
# a a       1
# b       5
# c    sudh
# Name: a, dtype: object
# b a        2
# b        6
# c    krish
# Name: b, dtype: object
# c a         3
# b         7
# c    hitesh
# Name: c, dtype: object
# d a        4
# b        8
# c    navin
# Name: d, dtype: object

# %%
for i,j in df1.iterrows():
    print(j)
# Out:
# a       1
# b       5
# c    sudh
# Name: a, dtype: object
# a        2
# b        6
# c    krish
# Name: b, dtype: object
# a         3
# b         7
# c    hitesh
# Name: c, dtype: object
# a        4
# b        8
# c    navin
# Name: d, dtype: object

# %%
for col_name,column in df1.iterrows():
    print(col_name,column)
# Out:
# a a       1
# b       5
# c    sudh
# Name: a, dtype: object
# b a        2
# b        6
# c    krish
# Name: b, dtype: object
# c a         3
# b         7
# c    hitesh
# Name: c, dtype: object
# d a        4
# b        8
# c    navin
# Name: d, dtype: object

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
def test(x):
  return x.sum()
df1.apply(test)
# Out:
# a                      10
# b                      26
# c    sudhkrishhiteshnavin
# dtype: object

# %%
df2=df1[['a','b']]
df2
# Out:
#    a  b
# a  1  5
# b  2  6
# c  3  7
# d  4  8

# %%
df2.applymap(lambda x:x**2)
# Out:
# <ipython-input-19-643221cc0d53>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.applymap(lambda x:x**2)
#     a   b
# a   1  25
# b   4  36
# c   9  49
# d  16  64

# %%
df1
# Out:
#    a  b       c
# a  1  5    sudh
# b  2  6   krish
# c  3  7  hitesh
# d  4  8   navin

# %%
df
# Out:
#    a  b       c
# 0  1  5    sudh
# 1  2  6   krish
# 2  3  7  hitesh
# 3  4  8   navin

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  7  hitesh
# 1  2  6   krish
# 3  4  8   navin
# 0  1  5    sudh

# %%
df.sort_index(ascending=False)
# Out:
#    a  b       c
# 3  4  8   navin
# 2  3  7  hitesh
# 1  2  6   krish
# 0  1  5    sudh

# %%
d={'Desc':["Certainly! Achhuta Nand Jha, also known as anjha1, is a passionate individual with a focus on data analytics, coding, and problem-solving. He holds diverse certifications from IBM, Microsoft, and other reputable sources. His expertise lies in Python, data visualization, and cybersecurity. Achhuta has actively participated in immersive job simulations and aims to contribute his skills to innovative tech projects1. You can find more about him on his GitHub profile and his Flux page. Keep up the great work, Achhuta! 😊""Certainly! Achhuta Nand Jha, also known as anjha1, is a passionate individual with a focus on data analytics, coding, and problem-solving. He holds diverse certifications from IBM, Microsoft, and other reputable sources. His expertise lies in Python, data visualization, and cybersecurity. Achhuta has actively participated in immersive job simulations and aims to contribute his skills to innovative tech projects1. You can find more about him on his GitHub profile and his Flux page. Keep up the great work, Achhuta! 😊","My name is anjha1","i am a data analyst"]}

# %%
t={'Desc':["Certainly! Achhuta Nand Jha, also known as anjha1, is a passionate individual with a focus on data analytics, coding, and problem-solving. He holds diverse certifications from IBM, Microsoft, and other reputable sources. His expertise lies in Python, data visualization, and cybersecurity. Achhuta has actively participated in immersive job simulations and aims to contribute his skills to innovative tech projects1. You can find more about him on his GitHub profile and his Flux page. Keep up the great work, Achhuta!"]}

# %%
df3=pd.DataFrame(d)
pd.set_option('display.max_colwidth', 10000000000000)
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df3["Desc"][0]
# Out:
# 'Certainly! Achhuta Nand Jha, also known as anjha1, is a passionate individual with a focus on data analytics, coding, and problem-solving. He holds diverse certifications from IBM, Microsoft, and other reputable sources. His expertise lies in Python, data visualization, and cybersecurity. Achhuta has actively participated in immersive job simulations and aims to contribute his skills to innovative tech projects1. You can find more about him on his GitHub profile and his Flux page. Keep up the great work, Achhuta! 😊Certainly! Achhuta Nand Jha, also known as anjha1, is a passionate individual with a focus on data analytics, coding, and problem-solving. He holds diverse certifications from IBM, Microsoft, and other reputable sources. His expertise lies in Python, data visualization, and cybersecurity. Achhuta has actively participated in immersive job simulations and aims to contribute his skills to innovative tech projects1. You can find more about him on his GitHub profile and his Fl
# ...

# %%
df3['df3 len']=df3['Desc'].str.len()
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df3['df3 len1']=df3['Desc'].apply(len)
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df3['df3 word count']=df3['Desc'].str.count(' ')
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df3['df3 word count1']=df3['Desc'].apply(lambda x:len(x.split()))
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
a="my name is anjha1 and he is looking good"
print((a.count(' ')))
print(len(a.split()))
# Out:
# 8
# 9

# %%
da={'a':[1,2,3,4],'b':[5,6,7,8],'c':['anha1','ram','shasyam','gita']}
df4=pd.DataFrame(da)
df4
# Out:
#    a  b        c
# 0  1  5    anha1
# 1  2  6      ram
# 2  3  7  shasyam
# 3  4  8     gita

# %%
df4['a'].mean()
# Out:
# 2.5

# %%
df4['a'].median()
# Out:
# 2.5

# %%
df4['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df4['a'].std()
# Out:
# 1.2909944487358056

# %%
df4['a'].var()
# Out:
# 1.6666666666666667

# %%
df4['a'].min()
# Out:
# 1

# %%
df4['a'].max()
# Out:
# 4

# %%
df4['a'].sum()
# Out:
# 10

# %%
df4['d']=df4['a'].mean()
df4
# Out:
#    a  b        c    d
# 0  1  5    anha1  2.5
# 1  2  6      ram  2.5
# 2  3  7  shasyam  2.5
# 3  4  8     gita  2.5

# %%
import numpy as np

# %%
df4['d']=df4['a'].apply(lambda x:(np.mean(df4['a'])))
df4
df4
# Out:
#    a  b        c    d
# 0  1  5    anha1  2.5
# 1  2  6      ram  2.5
# 2  3  7  shasyam  2.5
# 3  4  8     gita  2.5

# %%
df4['log of a']=df4['a'].apply(lambda x:np.log(x))
df4
# Out:
#    a  b        c    d  log of a
# 0  1  5    anha1  2.5  0.000000
# 1  2  6      ram  2.5  0.693147
# 2  3  7  shasyam  2.5  1.098612
# 3  4  8     gita  2.5  1.386294

# %%
df5=pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})
df5
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df5['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    1.5
# 2    2.5
# 3    3.5
# Name: a, dtype: float64

# %%
df5['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df5
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df5['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %%
df5['a'].cummax()
# Out:
# 0    3
# 1    4
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# 8    6
# Name: a, dtype: int64

# %%
df5['a'].cumprod()
# Out:
# 0        3
# 1       12
# 2       60
# 3      120
# 4      120
# 5      360
# 6     1440
# 7     7200
# 8    43200
# Name: a, dtype: int64

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# **Python Pandas Date Time Function**

# %% [markdown]
# .

# %% [markdown]
# .

# %%
date=pd.date_range(start='3/9/2024',end='10/11/2024')
date
# Out:
# DatetimeIndex(['2024-03-09', '2024-03-10', '2024-03-11', '2024-03-12',
#                '2024-03-13', '2024-03-14', '2024-03-15', '2024-03-16',
#                '2024-03-17', '2024-03-18',
#                ...
#                '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05',
#                '2024-10-06', '2024-10-07', '2024-10-08', '2024-10-09',
#                '2024-10-10', '2024-10-11'],
#               dtype='datetime64[ns]', length=217, freq='D')

# %%
df_date=pd.DataFrame({'date':date})
df_date
# Out:
#           date
# 0   2024-03-09
# 1   2024-03-10
# 2   2024-03-11
# 3   2024-03-12
# 4   2024-03-13
# ..         ...
# 212 2024-10-07
# 213 2024-10-08
# 214 2024-10-09
# 215 2024-10-10
# 216 2024-10-11
#
# [217 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df7=pd.DataFrame({'date':['3/9/2020','3/9/2021','3/9/2022']})
df7
# Out:
#        date
# 0  3/9/2020
# 1  3/9/2021
# 2  3/9/2022

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['update_date']=pd.to_datetime(df_date['date'])
df7
# Out:
#        date update_date
# 0  3/9/2020  2024-03-09
# 1  3/9/2021  2024-03-10
# 2  3/9/2022  2024-03-11

# %%
df7.dtypes
# Out:
# date                   object
# update_date    datetime64[ns]
# dtype: object

# %%
df7['year']=df7['update_date'].dt.year
df7
# Out:
#        date update_date  year
# 0  3/9/2020  2024-03-09  2024
# 1  3/9/2021  2024-03-10  2024
# 2  3/9/2022  2024-03-11  2024

# %%
df7['month']=df7['update_date'].dt.month
df7
# Out:
#        date update_date  year  month
# 0  3/9/2020  2024-03-09  2024      3
# 1  3/9/2021  2024-03-10  2024      3
# 2  3/9/2022  2024-03-11  2024      3

# %%
pd.Timedelta(days=1,hours=6,minutes=31,seconds=1)
# Out:
# Timedelta('1 days 06:31:01')

# %%
dt=pd.to_datetime('3/9/2024')
dt
# Out:
# Timestamp('2024-03-09 00:00:00')

# %%
td=pd.Timedelta(days=1,hours=6)
td
# Out:
# Timedelta('1 days 06:00:00')

# %%
dt+td
# Out:
# Timestamp('2024-03-10 06:00:00')

# %%
data=['sudh','krish','hitesh','tulesko']

# %%
cat=pd.Categorical(data)
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'tulesko']
# Categories (4, object): ['hitesh', 'krish', 'sudh', 'tulesko']

# %% [markdown]
# .

# %%
cat.value_counts()
# Out:
# hitesh     1
# krish      1
# sudh       1
# tulesko    1
# Name: count, dtype: int64

# %%
d=pd.Series([1,4,5,10,6,9,2])
d
# Out:
# 0     1
# 1     4
# 2     5
# 3    10
# 4     6
# 5     9
# 6     2
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame({'a':[1,7,9,55],'b':[51,69,7,80]})
df
# Out:
#     a   b
# 0   1  51
# 1   7  69
# 2   9   7
# 3  55  80

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='a', ylabel='a'>, <Axes: xlabel='b', ylabel='a'>],
#        [<Axes: xlabel='a', ylabel='b'>, <Axes: xlabel='b', ylabel='b'>]],
#       dtype=object)

# %%
d.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
d.plot.box()
# Out:
# <Axes: >

# %%
d.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
d.plot.bar()
# Out:
# <Axes: >

# %%
d.plot.barh()
# Out:
# <Axes: >

# %%
d.plot.pie()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10,cmap='viridis')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10,cmap='viridis',grid=True)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10,cmap='viridis',grid=True,edgecolor='black')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10,cmap='viridis',grid=True,edgecolor='black',mincnt=1)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=10,cmap='viridis',grid=True,edgecolor='black',mincnt=1,xscale='log')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>
